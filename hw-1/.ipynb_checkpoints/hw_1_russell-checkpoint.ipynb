# %% [markdown]
# Required packages:
# - pandas
# - matplotlib
# - seaborn
# - Pillow
# - numpy

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
sns.set()

from PIL import Image
import numpy as np

# %matplotlib inline

# %% [markdown]
# ## 1.1
# ### (a)

# %%
df1 = pd.read_csv("expDat.txt", index_col=0)
# Print first five rows
df1.head()
# Out:
#    V1  V2  V3  V4  V5  V6  V7  V8  V9  V10  V11  V12  V13  V14  V15  V16  V17  \
# 1   1   0   0   2   2   0   2   3   2    3    2    3    3    5    1    1    1
# 2   2   2   2   2   0   0   3   2   0    1    0    1    3    0    2    3    2
# 3   3   2   3   2   3   2   2   2   2    2    2    6    2    4    3    2    2
# 4   0   4   1   2   3   3   2   2   1    1    0    2    4    2    4    2    0
# 5   6   2   1   2   0   5   1   2   4    1    1    5    2    2    4    5    2
#
#    V18  V19  V20
# 1    4    2    1
# 2    1    1    2
# 3    1    1    3
# 4    0    1    2
# 5    0    3    3

# %% [markdown]
# ### (b)

# %%
df1.plot(figsize=(20,10))

# %% [markdown]
# ### (c)

# %%
sns.pairplot(df1.ix[:, :5])

# %% [markdown]
# ### (d)
# # TODO

# %% [markdown]
# ## 1.2
# ### (a)

# %%
df2 = pd.read_csv("pca-data-3d.txt")
df2.head()
# Out:
#           x         y         z
# 0 -0.194263  0.223524 -0.211130
# 1  0.020346 -0.380149 -0.990472
# 2  0.832259  3.054901 -2.725782
# 3  0.776873  1.540465  1.269721
# 4 -0.025527  0.064696  0.088624

# %% [markdown]
# ### (b)

# %%
sns.pairplot(df2)

# %% [markdown]
# ### (c)

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df2['x'], df2['y'], df2['z'])

# %% [markdown]
# Looks like a wave/spiral thing?
#
# ### (d)
# # TODO

# %%
plt.figure(figsize=(8,8))
plt.scatter(df2['x'], df2['y'])
plt.xlabel('x')
plt.ylabel('y')

# %% [markdown]
# ## 1.3
# ### (a)

# %%
im = Image.open('natIMG.jpg')
data = np.asarray(im)

# Normalize data
data_norm = data * (1.0/data.max())

# %% [markdown]
# ### (b)
# # TODO
# Image does not look like it should (contrast)

# %%
plt.figure(figsize=(8,8))
plt.imshow(data_norm, clim=(np.min(data_norm), np.max(data_norm)))

# %% [markdown]
# ### (c)
# # TODO

# %% [markdown]
# ### (d)
# # TODO
